# %% [markdown]
# ## Links importantes
#
# http://www.fundamentus.com.br/consciente.php
#
# http://investidorjovem.com.br/achando-acoes-para-investir-a-formula-magica-de-joel-greenblatt

# %%
import pandas as pd
import numpy as np

# %%
class FormulaMagica:
    def __init__(self):
        self.df = pd.read_clipboard()
        self.df_original = df
        
        self.formata_dados()
        self.filtro()
        self.ordem()
        
    def filtro(self):
        self.df = self.df[(self.df['P/L'] > 1) & (self.df['P/L'] < 1500)]
        self.df = self.df[(self.df['ROIC'] > 0)]
        
    def ordem(self):
        # ROIC quanto maior melhor
        # eu ordeno por ordem de ROIC crescente e o primeiro recebe o valor 1 (pior) e o último recebe o maior valor (melhor)
        self.df.sort_values(by='ROIC', inplace=True)
        self.df.insert(3, 'ROIC Ordem', range(1, + len(self.df) + 1))
        
        # quanto maior o EV/EBIT pior
        self.df.sort_values(by='EV/EBIT', inplace=True, ascending=False)
        self.df.insert(3, 'EV/EBIT Ordem', range(1, + len(self.df) + 1))
        
        self.df['Ordem Formula'] = self.df['ROIC Ordem'] + self.df['EV/EBIT Ordem']
        self.df.sort_values(by='Ordem Formula', inplace=True, ascending=False)
        
    def formata_dados(self):
        self.df['Cotação'] = self.df['Cotação'].str.replace('.', '').str.replace(',', '.').astype('float64')
        self.df['P/L'] = self.df['P/L'].str.replace('.', '').str.replace(',', '.').astype('float64')
        self.df['EV/EBIT'] = self.df['EV/EBIT'].str.replace('.', '').str.replace(',', '.').str.replace('%', '').astype('float64')
        self.df['ROIC'] = self.df['ROIC'].str.replace('.', '').str.replace(',', '.').str.replace('%', '').astype('float64')

# %%
fm = FormulaMagica()
fm.df.head(10)
# Out:
#      Papel  Cotação     P/L  EV/EBIT Ordem  ROIC Ordem        P/VP    PSR  \
# 536  CTWR3   100.00    9.76            377         377       56,77  0,317
# 809  PLTO6    10.47   50.81            368         383  692.616,00  0,690
# 812  PLTO5    10.94   53.09            369         382  723.708,00  0,721
# 597  PTBL3     4.10   12.28            381         341        1,89  2,411
# 466  PTBL4     2.59    7.75            380         340        1,19  1,523
# 800  FRIO3    53.37   42.41            329         380        5,04  0,172
# 396  PMAM4     5.84    3.11            333         365        0,35  0,044
# 842  PQUN3    15.44  104.31            352         345        1,88  0,545
# 584  PMAM3    22.00   11.71            332         364        1,32  0,164
# 843  PQUN4    15.44  104.31            351         344        1,88  0,545
#
#     Div.Yield P/Ativo P/Cap.Giro      ...           ROIC      ROE Liq.2meses  \
# 536     0,00%   1,141       3,79      ...           5.52    4,94%        NaN
# 809     0,00%   0,901       2,90      ...       21227.00    8,78%        NaN
# 812     0,00%   0,942       3,03      ...       21227.00    8,78%        NaN
# 597     5,30%   0,371       3,21      ...           2.06  -22,53%        NaN
# 466     0,00%   0,234       2,03      ...           2.06  -22,53%        NaN
# 800     0,00%   0,151       1,82      ...          20.26    7,16%        NaN
# 396     0,00%   0,059       0,32      ...           3.06   -0,92%        NaN
# 842     0,00%   0,523       7,57      ...           2.28    5,19%        NaN
# 584     0,00%   0,220       1,21      ...           3.06   -0,92%        NaN
# 843     0,00%   0,523       7,57      ...           2.28    5,19%        NaN
#
#      Patrim. Líq Dív.Brut/ Patrim..1 Cresc. Rec.5a Ordem Formula
# 536      NaN NaN       NaN       NaN    NaN    NaN           754
# 809      NaN NaN       NaN       NaN    NaN    NaN           751
# 812      NaN NaN       NaN       NaN    NaN    NaN           751
# 597      NaN NaN       NaN       NaN    NaN    NaN           722
# 466      NaN NaN       NaN       NaN    NaN    NaN           720
# 800      NaN NaN       NaN       NaN    NaN    NaN           709
# 396      NaN NaN       NaN       NaN    NaN    NaN           698
# 842      NaN NaN       NaN       NaN    NaN    NaN           697
# 584      NaN NaN       NaN       NaN    NaN    NaN           696
# 843      NaN NaN       NaN       NaN    NaN    NaN           695
#
# [10 rows x 30 columns]

# %%
# lê os dados do clipboard.
# precisa selecionar a tabela do site: http://www.fundamentus.com.br/resultado.php
df = pd.read_clipboard()
dfOriginal = df

# %%
# converte os dados para números
df['Cotação'] = df['Cotação'].str.replace(',', '.').astype('float64')
df['P/L'] = df['P/L'].str.replace('.', '').str.replace(',', '.').astype('float64')
df['P/VP'] = df['P/VP'].str.replace('.', '').str.replace(',', '.').astype('float64')
df['PSR'] = df['PSR'].str.replace('.', '').str.replace(',', '.').astype('float64')
df['Div.Yield'] = df['Div.Yield'].str.replace(',', '.').str.replace('%', '').astype('float64') / 100
df['P/Ativo'] = df['P/Ativo'].str.replace('.', '').str.replace(',', '.').astype('float64')
df['P/Cap.Giro'] = df['P/Cap.Giro'].str.replace('.', '').str.replace(',', '.').astype('float64')
df['P/EBIT'] = df['P/EBIT'].str.replace('.', '').str.replace(',', '.').astype('float64')
df['P/Ativ Circ.Liq'] = df['P/Ativ Circ.Liq'].str.replace('.', '').str.replace(',', '.').astype('float64')
df['EV/EBIT'] = df['EV/EBIT'].str.replace('.', '').str.replace(',', '.').astype('float64')
df['Mrg Ebit'] = df['Mrg Ebit'].str.replace('.', '').str.replace(',', '.').str.replace('%', '').astype('float64') / 100
df['Mrg. Líq.'] = df['Mrg. Líq.'].str.replace('.', '').str.replace(',', '.').str.replace('%', '').astype('float64') / 100
df['Liq. Corr.'] = df['Liq. Corr.'].str.replace('.', '').str.replace(',', '.').astype('float64')
df['ROIC'] = df['ROIC'].str.replace('.', '').str.replace(',', '.').str.replace('%', '').astype('float64') / 100
df['ROE'] = df['ROE'].str.replace('.', '').str.replace(',', '.').str.replace('%', '').astype('float64') / 100
df['Liq.2meses'] = df['Liq.2meses'].str.replace('.', '').str.replace(',', '.').astype('float64')
df['Patrim. Líq'] = df['Patrim. Líq'].str.replace('.', '').str.replace(',', '.').astype('float64') / 1000
df['Dív.Brut/ Patrim.'] = df['Dív.Brut/ Patrim.'].str.replace('.', '').str.replace(',', '.').str.replace('%', '').astype('float64') / 100
df['Cresc. Rec.5a'] = df['Cresc. Rec.5a'].str.replace('.', '').str.replace(',', '.').str.replace('%', '').astype('float64') / 100

# filtros
df = df[(df['P/L'] > 1) & (df['P/L'] < 15)]
df = df[(df['ROE'] > 0)]
df = df[(df['Cresc. Rec.5a'] > 0)]
df = df[(df['Liq. Corr.'] > 1)]

# criar valor de acordo com a ordem dos dados
df.sort_values(by='P/L', inplace=True)
df.insert(3, 'P/L Ordem', range(1, + len(df) + 1))
df.sort_values(by='ROE', inplace=True, ascending=False)
df.insert(17, 'ROE Ordem', range(1, + len(df) + 1))

# criar nova coluna com a posição final
df['Ordem Formula'] = df['P/L Ordem'] + df['ROE Ordem']
df.sort_values(by='Ordem Formula', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'P/Ativ Circ.Liq'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-0667a9773d40> in <module>
#       8 df['P/Cap.Giro'] = df['P/Cap.Giro'].str.replace('.', '').str.replace(',', '.').astype('float64')
#       9 df['P/EBIT'] = df['P/EBIT'].str.replace('.', '').str.replace(',', '.').astype('float64')
# ---> 10 df['P/Ativ Circ.Liq'] = df['P/Ativ Circ.Liq'].str.replace('.', '').str.replace(',', '.').astype('float64')
#      11 df['EV/EBIT'] = df['EV/EBIT'].str.replace('.', '').str.replace(',', '.').astype('float64')
#      12 df['Mrg Ebit'] = df['Mrg Ebit'].str.replace('.', '').str.replace(',', '.').str.replace('%', '').astype('float64') / 100
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'P/Ativ Circ.Liq'

# %%
df.head(10)
# Out:
#      Papel  Cotação   P/L  P/L Ordem  P/VP    PSR  Div.Yield  P/Ativo  \
# 144  EALT4     4.80  3.14          3  1.14  0.522     0.6104    0.379
# 154  CSNA3     9.90  4.27          9  1.97  0.668     0.0651    0.297
# 146  EALT3     5.10  3.34          4  1.21  0.554     0.5223    0.403
# 143  LLIS3    26.58  3.10          2  0.62  1.102     0.0704    0.364
# 162  CRPG6    24.70  4.68         15  1.21  0.948     0.1537    0.864
# 166  CRPG5    27.45  5.20         18  1.35  1.054     0.1383    0.960
# 168  CRPG3    29.45  5.58         20  1.45  1.131     0.0000    1.030
# 192  UNIP3    39.00  6.90         28  2.83  0.984     0.0272    0.796
# 163  CCPR3     9.75  4.80         16  0.98  2.280     0.0000    0.309
# 151  EMAE4    15.00  3.77          6  0.65  2.564     0.0623    0.431
#
#      P/Cap.Giro  P/EBIT      ...        Mrg. Líq.  Liq. Corr.    ROIC     ROE  \
# 144       11.03   10.71      ...           0.1658        1.09  0.0390  0.3616
# 154        5.22    4.21      ...           0.1610        1.25  0.0843  0.4620
# 146       11.72   11.38      ...           0.1658        1.09  0.0390  0.3616
# 143       16.34    4.86      ...           0.3802        1.10  0.0883  0.2014
# 162        1.33    4.28      ...           0.2025        5.97  0.2500  0.2593
# 166        1.48    4.76      ...           0.2025        5.97  0.2500  0.2593
# 168        1.59    5.11      ...           0.2025        5.97  0.2500  0.2593
# 192        5.35    4.35      ...           0.1456        1.49  0.2496  0.4101
# 163        3.19    5.17      ...           0.5830        2.19  0.0699  0.2034
# 151        2.43  -50.15      ...           0.6794        3.33 -0.0100  0.1723
#
#      ROE Ordem   Liq.2meses  Patrim. Líq  Dív.Brut/ Patrim.  Cresc. Rec.5a  \
# 144          6     20545.20      94980.0             0.0072         0.0054
# 154          2  70706600.00    6961570.0             0.0437         0.0408
# 146          7       387.83      94980.0             0.0072         0.0054
# 143         20    179225.00    2197350.0             0.0052         0.1445
# 162         11     91289.80     472197.0             0.0000         0.1297
# 166         10    415418.00     472197.0             0.0000         0.1297
# 168         12      2148.79     472197.0             0.0000         0.1297
# 192          5    573444.00    1151980.0             0.0111         0.6229
# 163         18    584990.00    1194580.0             0.0150         0.1022
# 151         28    114698.00     852180.0             0.0010         0.0752
#
#      Ordem Formula
# 144              9
# 154             11
# 146             11
# 143             22
# 162             26
# 166             28
# 168             32
# 192             33
# 163             34
# 151             34
#
# [10 rows x 23 columns]
